# 2024-07-25 17:30:00,168.1200,169.2500,168.0600,168.3600,336655
# 2024-07-25 17:15:00,168.0200,168.2500,168.0100,168.0900,11209
# 2024-07-25 17:00:00,168.4400,168.4500,168.0000,168.0600,8533
# 2024-07-25 16:45:00,168.1700,169.6790,157.0860,168.4400,400826
# 2024-07-25 16:30:00,168.7200,169.1600,168.0000,168.1800,37042
# 2024-07-25 16:15:00,169.1600,170.0200,168.6400,168.7300,81714
# 2024-07-25 16:00:00,169.0800,169.3800,168.4900,168.7700,5189883
# 2024-07-25 15:45:00,170.7500,170.8000,169.0500,169.0800,2990463
# 2024-07-25 15:30:00,171.8600,171.9100,170.6300,170.7600,800519
# 2024-07-25 15:15:00,170.8100,172.0000,170.7900,171.8800,694666
# 2024-07-25 15:00:00,171.0500,171.4100,170.7400,170.8100,683843
# 2024-07-25 14:45:00,171.2300,171.3200,170.6100,171.0550,746285
# 2024-07-25 14:30:00,170.4900,171.3000,170.4600,171.2180,806517
# 2024-07-25 14:15:00,171.1550,171.2400,169.9550,170.4980,1888010
# 2024-07-25 14:00:00,174.4800,174.5800,171.0400,171.1310,2801359
# 2024-07-25 13:45:00,174.4780,174.5600,174.0800,174.4700,372890
# 2024-07-25 13:30:00,174.1500,174.5400,173.9900,174.4600,345618
# 2024-07-25 13:15:00,174.7400,174.7700,174.0200,174.1200,372313
# 2024-07-25 13:00:00,174.6400,175.2000,174.5600,174.7060,396138
# 2024-07-25 12:45:00,174.4030,174.7900,174.1650,174.6000,285639
# 2024-07-25 12:30:00,174.6100,174.7700,174.3300,174.3900,295862
# 2024-07-25 12:15:00,174.2800,174.9100,174.1900,174.6050,377596
# 2024-07-25 12:00:00,173.7400,174.3100,173.3900,174.2900,379038
# 2024-07-25 11:45:00,173.3600,173.8800,173.1800,173.7400,407401
# 2024-07-25 11:30:00,173.8500,173.9700,173.0100,173.3600,413909
# 2024-07-25 11:15:00,174.3300,174.4690,173.5400,173.8500,496061
# 2024-07-25 11:00:00,173.8600,174.3400,173.2700,174.3300,608654

# %%
import pandas as pd
import requests
from io import StringIO
df = pd.read_csv(StringIO(data))

print(df.head())
print(len(df['close']))
# Out:
#              timestamp     open    high     low   close  volume
# 0  2024-07-26 19:45:00  168.680  168.76  168.59  168.68    2122
# 1  2024-07-26 19:30:00  168.680  168.76  168.65  168.68     681
# 2  2024-07-26 19:15:00  168.754  168.96  168.65  168.68    2151
# 3  2024-07-26 19:00:00  168.900  168.96  168.76  168.77     560
# 4  2024-07-26 18:45:00  168.719  168.99  168.68  168.89    1865
# 100

# %%
from matplotlib import pyplot as plt
plt.plot(df['open'])
plt.plot(df['close'])
plt.show()

# %%
print(df['timestamp'])
# Out:
# 0     2024-07-26 19:45:00
# 1     2024-07-26 19:30:00
# 2     2024-07-26 19:15:00
# 3     2024-07-26 19:00:00
# 4     2024-07-26 18:45:00
#              ...
# 95    2024-07-25 12:00:00
# 96    2024-07-25 11:45:00
# %%
print(df['close'])
# Out:
# 0     168.68
# 1     168.68
# 2     168.68
# 3     168.77
# 4     168.89
#        ...
# 95    174.29
# 96    173.74
# 97    173.36
# 98    173.85
# 99    174.33
# Name: close, Length: 100, dtype: float64

# %%
close_list=df['close'].to_list()
print(close_list)
# Out:
# [168.68, 168.68, 168.68, 168.77, 168.89, 168.68, 168.69, 168.615, 168.65, 168.57, 168.61, 168.65, 168.69, 168.64, 168.64, 168.72, 168.67, 169.04, 168.61, 168.62, 168.34, 168.77, 168.55, 168.59, 168.785, 168.53, 169.41, 169.47, 169.545, 169.21, 168.58, 168.74, 168.305, 167.88, 167.91, 168.272, 168.23, 168.09, 167.73, 166.55, 166.72, 167.09, 168.79, 169.14, 168.858, 169.39, 169.51, 169.71, 169.72, 169.57, 169.41, 169.69, 170.0, 170.28, 170.24, 170.4, 170.3, 170.1, 170.06, 170.35, 170.6, 170.33, 170.39, 169.97, 168.15, 168.06, 168.5, 168.49, 168.39, 168.54, 168.55, 168.3, 167.82, 168.36, 168.09, 168.06, 168.44, 168.18, 168.73, 168.77, 169.08, 170.76, 171.88, 170.81, 171.055, 171.218, 170.498, 171.131, 174.47, 174.46, 174.12, 174.706, 174.6, 174.39, 174.605, 174.29, 173.74, 173.36, 173.85, 174.33]

# %%
import pandas as pd
import requests
from io import StringIO

ticker="GOOG"
url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={ticker}&topic=finance&time_from=20240724T0000&time_to=20240724T2359&apikey=COOFAIV9AV9SVV19'
r = requests.get(url)
data = r.json() # Parse the response as JSON

# Assuming the relevant data is in the 'feed' key
df = pd.DataFrame(data.get('feed', []))

#print(df)

print(df.head())
print(len(df['title']))
print("")
print(df['time_published'])
# Out:
#                                                title  \
# 0  United States Mint Releases 2024 American Inno...
# 1  Huawei plans tri-fold smartphone as Apple weig...
# 2  Jim Cramer examines Wednesday's brutal tech se...
# 3  Producer Narada Michael Walden and Singer-Song...
# 4  Tiny 500Gh home Bitcoin mining device produced...
#
#                                                  url   time_published  \
# 0  https://www.benzinga.com/pressreleases/24/07/g...  20240724T230734
# 1  https://www.scmp.com/tech/big-tech/article/327...  20240724T230010
# 2  https://www.cnbc.com/2024/07/24/jim-cramer-exa...  20240724T225302
# 3  https://www.benzinga.com/pressreleases/24/07/g...  20240724T223821
# 4  https://cointelegraph.com/news/tiny-500gh-home...  20240724T215915
#
#                authors                                            summary  \
# 0     [Globe Newswire]  WASHINGTON, July 24, 2024 ( GLOBE NEWSWIRE ) -...
# 1          [Iris Deng]  Apple is reportedly working on a clamshell-sty...
# 2                   []  CNBC's Jim Cramer looked at what caused Wednes...
# 3     [Globe Newswire]  Los Angeles, CA , July 24, 2024 ( GLOBE NEWSWI...
# 4  [Christopher Roark]  The device, called a 'Bitaxe,' successfully mi...
#
#                                         banner_image  \
# 0  https://ml.globenewswire.com/media/8d9779fa-e6...
# 1  https://img.i-scmp.com/cdn-cgi/image/fit=conta...
# 2                                               None
# 3  https://ml.globenewswire.com/Resource/Download...
# 4  https://images.cointelegraph.com/cdn-cgi/image...
#
#                      source category_within_source      source_domain  \
# 0                  Benzinga                General   www.benzinga.com
# 1  South China Morning Post              Companies       www.scmp.com
# 2                      CNBC               Top News       www.cnbc.com
# 3                  Benzinga                General   www.benzinga.com
# 4             Cointelegraph                    n/a  cointelegraph.com
#
#                                               topics  overall_sentiment_score  \
# 0  [{'topic': 'Technology', 'relevance_score': '1...                 0.314531
# 1  [{'topic': 'Technology', 'relevance_score': '1...                 0.144264
# 2  [{'topic': 'Life Sciences', 'relevance_score':...                 0.039067
# 3  [{'topic': 'Technology', 'relevance_score': '1...                 0.541221
# 4  [{'topic': 'Technology', 'relevance_score': '1...                -0.057454
#
#   overall_sentiment_label                                   ticker_sentiment
# 0        Somewhat-Bullish  [{'ticker': 'GOOG', 'relevance_score': '0.0388...
# 1                 Neutral  [{'ticker': 'SSNLF', 'relevance_score': '0.216...
# 2                 Neutral  [{'ticker': 'GOOG', 'relevance_score': '0.1524...
# 3                 Bullish  [{'ticker': 'GOOG', 'relevance_score': '0.0807...
# 4                 Neutral  [{'ticker': 'GOOG', 'relevance_score': '0.1003...
# 50
#
# 0     20240724T230734
# 1     20240724T230010
# 2     20240724T225302
# 3     20240724T223821
# 4     20240724T215915
# 5     20240724T204400
# 6     20240724T203720
# 7     20240724T203503
# 8     20240724T201033
# 9     20240724T200559
# 10    20240724T195609
# 11    20240724T195523
# 12    20240724T195044
# 13    20240724T194931
# 14    20240724T194645
# 15    20240724T194354
# 16    20240724T193134
# 17    20240724T193042
# 18    20240724T191714
# 19    20240724T191106
# 20    20240724T191058
# 21    20240724T190904
# 22    20240724T190530
# 23    20240724T190252
# 24    20240724T184118
# 25    20240724T183414
# 26    20240724T182925
# 27    20240724T182757
# 28    20240724T182712
# 29    20240724T182542
# 30    20240724T182436
# 31    20240724T181740
# 32    20240724T180347
# 33    20240724T180259
# 34    20240724T175555
# 35    20240724T175519
# 36    20240724T174937
# 37    20240724T174901
# 38    20240724T174835
# 39    20240724T174652
# 40    20240724T173851
# 41    20240724T172320
# 42    20240724T171751
# 43    20240724T171720
# 44    20240724T171715
# 45    20240724T171705
# 46    20240724T171517
# 47    20240724T171514
# 48    20240724T171330
# 49    20240724T171129
# Name: time_published, dtype: object

# %%
df['overall_sentiment_score'].head(), df['summary'].head()
# Out:
# (0    0.314531
#  1    0.144264
#  2    0.039067
#  3    0.541221
#  4   -0.057454
#  Name: overall_sentiment_score, dtype: float64,
#  0    WASHINGTON, July 24, 2024 ( GLOBE NEWSWIRE ) -...
#  1    Apple is reportedly working on a clamshell-sty...
#  2    CNBC's Jim Cramer looked at what caused Wednes...
#  3    Los Angeles, CA , July 24, 2024 ( GLOBE NEWSWI...
#  4    The device, called a 'Bitaxe,' successfully mi...
#  Name: summary, dtype: object)

# %%
df['summary'].head()
# Out:
# 0    WASHINGTON, July 24, 2024 ( GLOBE NEWSWIRE ) -...
# 1    Apple is reportedly working on a clamshell-sty...
# 2    CNBC's Jim Cramer looked at what caused Wednes...
# 3    Los Angeles, CA , July 24, 2024 ( GLOBE NEWSWI...
# 4    The device, called a 'Bitaxe,' successfully mi...
# Name: summary, dtype: object

# %%
df['url']
# Out:
# 0     https://www.benzinga.com/pressreleases/24/07/g...
# 1     https://www.scmp.com/tech/big-tech/article/327...
# 2     https://www.cnbc.com/2024/07/24/jim-cramer-exa...
# 3     https://www.benzinga.com/pressreleases/24/07/g...
# 4     https://cointelegraph.com/news/tiny-500gh-home...
# 5     https://www.zacks.com/stock/news/2308225/googl...
# 6     https://www.benzinga.com/general/24/07/3994357...
# 7     https://decrypt.co/241465/proton-wallet-launch...
# 8     https://www.fool.com/investing/2024/07/24/why-...
# 9                          https://consent.google.com/m
# 10    https://www.fool.com/data-news/2024/07/24/cme-...
# 11                         https://consent.google.com/m
# 12    https://www.benzinga.com/news/24/07/39941711/w...
# 13    https://www.fool.com/investing/2024/07/24/why-...
# 14    https://www.benzinga.com/general/gaming/24/07/...
# 15    https://www.business-standard.com/companies/ne...
# 16                         https://consent.google.com/m
# 17                         https://consent.google.com/m
# 18                         https://consent.google.com/m
# 19                         https://consent.google.com/m
# 20                         https://consent.google.com/m
# 21                         https://consent.google.com/m
# 22                         https://consent.google.com/m
# 23                         https://consent.google.com/m
# 24                         https://consent.google.com/m
# 25    https://www.benzinga.com/general/sports/24/07/...
# 26                         https://consent.google.com/m
# 27                         https://consent.google.com/m
# 28                         https://consent.google.com/m
# 29                         https://consent.google.com/m
# 30                         https://consent.google.com/m
# 31                         https://consent.google.com/m
# 32                         https://consent.google.com/m
# 33    https://www.benzinga.com/markets/equities/24/0...
# 34                         https://consent.google.com/m
# 35                         https://consent.google.com/m
# 36                         https://consent.google.com/m
# 37                         https://consent.google.com/m
# 38                         https://consent.google.com/m
# 39    https://www.cnbc.com/2024/07/24/renewable-ener...
# 40    https://www.fool.com/data-news/2024/07/24/alph...
# 41    https://www.benzinga.com/news/24/07/39938971/c...
# 42                         https://consent.google.com/m
# 43    https://www.benzinga.com/analyst-ratings/analy...
# 44                         https://consent.google.com/m
# 45                         https://consent.google.com/m
# 46    https://www.fool.com/earnings/call-transcripts...
# 47    https://www.fool.com/earnings/call-transcripts...
# 48    https://www.benzinga.com/markets/cryptocurrenc...
# 49    https://cointelegraph.com/news/polymarket-clin...
# Name: url, dtype: object

# %%
"""import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Initialize Vader's SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Example text
text = "This movie was absolutely amazing! I would highly recommend it."

# Analyze sentiment
sentiment = analyzer.polarity_scores(text)

# Print sentiment scores
print(sentiment)"""
# Out:
# 'import nltk\nfrom nltk.sentiment.vader import SentimentIntensityAnalyzer\n\n# Initialize Vader\'s SentimentIntensityAnalyzer\nanalyzer = SentimentIntensityAnalyzer()\n\n# Example text\ntext = "This movie was absolutely amazing! I would highly recommend it."\n\n# Analyze sentiment\nsentiment = analyzer.polarity_scores(text)\n\n# Print sentiment scores\nprint(sentiment)'

# %%
summary_list=df['summary'].to_list()

# %%
import nltk

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

sentiment_list=[]
for i in summary_list:
    temp=analyzer.polarity_scores(i)
    sentiment_list.append(temp)

# %%
sentiment_list
# Out:
# [{'neg': 0.033, 'neu': 0.826, 'pos': 0.141, 'compound': 0.7269},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.4767},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.121, 'neu': 0.669, 'pos': 0.209, 'compound': 0.2732},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.092, 'neu': 0.833, 'pos': 0.074, 'compound': -0.2023},
#  {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.5267},
#  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215},
#  {'neg': 0.0, 'neu': 0.903, 'pos': 0.097, 'compound': 0.1027},
#  {'neg': 0.0, 'neu': 0.604, 'pos': 0.396, 'compound': 0.7096},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.103, 'neu': 0.742, 'pos': 0.155, 'compound': 0.3612},
#  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.5994},
#  {'neg': 0.0, 'neu': 0.949, 'pos': 0.051, 'compound': 0.34},
#  {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.4522},
#  {'neg': 0.394, 'neu': 0.469, 'pos': 0.136, 'compound': -0.7579},
#  {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'compound': 0.5574},
#  {'neg': 0.277, 'neu': 0.723, 'pos': 0.0, 'compound': -0.5574},
#  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.4767},
#  {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.296},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.34},
#  {'neg': 0.077, 'neu': 0.667, 'pos': 0.256, 'compound': 0.7906},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.6369},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.074, 'neu': 0.784, 'pos': 0.142, 'compound': 0.34},
#  {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'compound': -0.7579},
#  {'neg': 0.065, 'neu': 0.79, 'pos': 0.145, 'compound': 0.6757},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.1779},
#  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106},
#  {'neg': 0.052, 'neu': 0.9, 'pos': 0.047, 'compound': -0.0516},
#  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.1655},
#  {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.886},
#  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.1655},
#  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.1655},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.084, 'neu': 0.837, 'pos': 0.08, 'compound': -0.0516},
#  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.5267}]

# %%
compound_list=[]
for i in sentiment_list:
    temp=i.get('compound')
    compound_list.append(temp)
compound_list
# Out:
# [0.7269,
#  0.0,
#  -0.4767,
#  0.0,
#  0.2732,
#  0.0,
#  -0.2023,
#  0.5267,
#  0.4215,
#  0.1027,
#  0.7096,
#  0.0,
#  0.3612,
#  0.5994,
#  0.34,
#  0.4522,
#  -0.7579,
#  0.5574,
#  -0.5574,
#  0.4767,
#  -0.296,
#  0.0,
#  0.0,
#  0.0,
#  0.34,
#  0.7906,
#  0.0,
#  0.0,
#  0.0,
#  0.6369,
#  0.0,
#  0.34,
#  -0.7579,
#  0.6757,
#  0.0,
#  0.4404,
#  0.0,
#  0.0,
#  0.0,
#  0.1779,
#  0.5106,
#  -0.0516,
#  -0.1655,
#  0.886,
#  -0.1655,
#  -0.1655,
#  0.0,
#  0.0,
#  -0.0516,
#  0.5267]

# %%
df['overall_sentiment_score']
# Out:
# 0     0.314531
# 1     0.144264
# 2     0.039067
# 3     0.541221
# 4    -0.057454
# 5     0.207244
# 6     0.103121
# 7     0.087654
# 8     0.043837
# 9     0.086343
# 10    0.376996
# 11    0.086343
# 12    0.142465
# 13    0.182052
# 14    0.508850
# 15    0.356618
# 16    0.086343
# 17    0.086343
# 18    0.086343
# 19    0.086343
# 20    0.086343
# 21    0.086343
# 22    0.086343
# 23    0.086343
# 24    0.086343
# 25    0.360795
# 26    0.086343
# 27    0.086343
# 28    0.086343
# 29    0.086343
# 30    0.086343
# 31    0.086343
# 32    0.086343
# 33   -0.032187
# 34    0.086343
# 35    0.086343
# 36    0.086343
# 37    0.086343
# 38    0.086343
# 39    0.128916
# 40    0.253210
# 41   -0.060348
# 42    0.086343
# 43    0.254355
# 44    0.086343
# 45    0.086343
# 46    0.283085
# 47    0.283085
# 48   -0.106378
# 49    0.156543
# Name: overall_sentiment_score, dtype: float64

# %%
close_list
# Out:
# [168.68,
#  168.68,
#  168.68,
#  168.77,
#  168.89,
#  168.68,
#  168.69,
#  168.615,
#  168.65,
#  168.57,
#  168.61,
#  168.65,
#  168.69,
#  168.64,
#  168.64,
#  168.72,
#  168.67,
#  169.04,
#  168.61,
#  168.62,
#  168.34,
#  168.77,
#  168.55,
#  168.59,
#  168.785,
#  168.53,
#  169.41,
#  169.47,
#  169.545,
#  169.21,
#  168.58,
#  168.74,
#  168.305,
#  167.88,
#  167.91,
#  168.272,
#  168.23,
#  168.09,
#  167.73,
#  166.55,
#  166.72,
#  167.09,
#  168.79,
#  169.14,
#  168.858,
#  169.39,
#  169.51,
#  169.71,
#  169.72,
#  169.57,
#  169.41,
#  169.69,
#  170.0,
#  170.28,
#  170.24,
#  170.4,
#  170.3,
#  170.1,
#  170.06,
#  170.35,
#  170.6,
#  170.33,
#  170.39,
#  169.97,
#  168.15,
#  168.06,
#  168.5,
#  168.49,
#  168.39,
#  168.54,
#  168.55,
#  168.3,
#  167.82,
#  168.36,
#  168.09,
#  168.06,
#  168.44,
#  168.18,
#  168.73,
#  168.77,
#  169.08,
#  170.76,
#  171.88,
#  170.81,
#  171.055,
#  171.218,
#  170.498,
#  171.131,
#  174.47,
#  174.46,
#  174.12,
#  174.706,
#  174.6,
#  174.39,
#  174.605,
#  174.29,
#  173.74,
#  173.36,
#  173.85,
#  174.33]

# %%
time_list
# Out:
# ['2024-07-26 19:45:00',
#  '2024-07-26 19:30:00',
#  '2024-07-26 19:15:00',
#  '2024-07-26 19:00:00',
#  '2024-07-26 18:45:00',
#  '2024-07-26 18:30:00',
#  '2024-07-26 18:15:00',
#  '2024-07-26 18:00:00',
#  '2024-07-26 17:45:00',
#  '2024-07-26 17:30:00',
#  '2024-07-26 17:15:00',
#  '2024-07-26 17:00:00',
#  '2024-07-26 16:45:00',
#  '2024-07-26 16:30:00',
#  '2024-07-26 16:15:00',
#  '2024-07-26 16:00:00',
#  '2024-07-26 15:45:00',
#  '2024-07-26 15:30:00',
#  '2024-07-26 15:15:00',
#  '2024-07-26 15:00:00',
#  '2024-07-26 14:45:00',
#  '2024-07-26 14:30:00',
#  '2024-07-26 14:15:00',
#  '2024-07-26 14:00:00',
#  '2024-07-26 13:45:00',
#  '2024-07-26 13:30:00',
#  '2024-07-26 13:15:00',
#  '2024-07-26 13:00:00',
#  '2024-07-26 12:45:00',
#  '2024-07-26 12:30:00',
#  '2024-07-26 12:15:00',
#  '2024-07-26 12:00:00',
#  '2024-07-26 11:45:00',
#  '2024-07-26 11:30:00',
#  '2024-07-26 11:15:00',
#  '2024-07-26 11:00:00',
#  '2024-07-26 10:45:00',
#  '2024-07-26 10:30:00',
#  '2024-07-26 10:15:00',
#  '2024-07-26 10:00:00',
#  '2024-07-26 09:45:00',
#  '2024-07-26 09:30:00',
#  '2024-07-26 09:15:00',
#  '2024-07-26 09:00:00',
#  '2024-07-26 08:45:00',
#  '2024-07-26 08:30:00',
#  '2024-07-26 08:15:00',
#  '2024-07-26 08:00:00',
#  '2024-07-26 07:45:00',
#  '2024-07-26 07:30:00',
#  '2024-07-26 07:15:00',
#  '2024-07-26 07:00:00',
#  '2024-07-26 06:45:00',
#  '2024-07-26 06:30:00',
#  '2024-07-26 06:15:00',
#  '2024-07-26 06:00:00',
#  '2024-07-26 05:45:00',
#  '2024-07-26 05:30:00',
#  '2024-07-26 05:15:00',
#  '2024-07-26 05:00:00',
#  '2024-07-26 04:45:00',
#  '2024-07-26 04:30:00',
#  '2024-07-26 04:15:00',
#  '2024-07-26 04:00:00',
#  '2024-07-25 19:45:00',
#  '2024-07-25 19:30:00',
#  '2024-07-25 19:15:00',
#  '2024-07-25 19:00:00',
#  '2024-07-25 18:45:00',
#  '2024-07-25 18:30:00',
#  '2024-07-25 18:15:00',
#  '2024-07-25 18:00:00',
#  '2024-07-25 17:45:00',
#  '2024-07-25 17:30:00',
#  '2024-07-25 17:15:00',
#  '2024-07-25 17:00:00',
#  '2024-07-25 16:45:00',
#  '2024-07-25 16:30:00',
#  '2024-07-25 16:15:00',
#  '2024-07-25 16:00:00',
#  '2024-07-25 15:45:00',
#  '2024-07-25 15:30:00',
#  '2024-07-25 15:15:00',
#  '2024-07-25 15:00:00',
#  '2024-07-25 14:45:00',
#  '2024-07-25 14:30:00',
#  '2024-07-25 14:15:00',
#  '2024-07-25 14:00:00',
#  '2024-07-25 13:45:00',
#  '2024-07-25 13:30:00',
#  '2024-07-25 13:15:00',
#  '2024-07-25 13:00:00',
#  '2024-07-25 12:45:00',
#  '2024-07-25 12:30:00',
#  '2024-07-25 12:15:00',
#  '2024-07-25 12:00:00',
#  '2024-07-25 11:45:00',
#  '2024-07-25 11:30:00',
#  '2024-07-25 11:15:00',
#  '2024-07-25 11:00:00']

# %%
from matplotlib import pyplot as plt
from matplotlib import dates
converted_dates = dates.datestr2num(time_list)
print(converted_dates)

# Assuming close_list and compound_list are defined and contain numerical data

plt.plot(converted_dates, close_list)
plt.xlabel('Dates')  # Add x-axis label
plt.ylabel('Close list')  # Add y-axis label
plt.title('Scatter Plot of Close and date Values')  # Add title
plt.show()
# Out:
# [19930.82291667 19930.8125     19930.80208333 19930.79166667
#  19930.78125    19930.77083333 19930.76041667 19930.75
#  19930.73958333 19930.72916667 19930.71875    19930.70833333
#  19930.69791667 19930.6875     19930.67708333 19930.66666667
#  19930.65625    19930.64583333 19930.63541667 19930.625
#  19930.61458333 19930.60416667 19930.59375    19930.58333333
#  19930.57291667 19930.5625     19930.55208333 19930.54166667
#  19930.53125    19930.52083333 19930.51041667 19930.5
#  19930.48958333 19930.47916667 19930.46875    19930.45833333
#  19930.44791667 19930.4375     19930.42708333 19930.41666667
#  19930.40625    19930.39583333 19930.38541667 19930.375
#  19930.36458333 19930.35416667 19930.34375    19930.33333333
#  19930.32291667 19930.3125     19930.30208333 19930.29166667
#  19930.28125    19930.27083333 19930.26041667 19930.25
#  19930.23958333 19930.22916667 19930.21875    19930.20833333
#  19930.19791667 19930.1875     19930.17708333 19930.16666667
#  19929.82291667 19929.8125     19929.80208333 19929.79166667
#  19929.78125    19929.77083333 19929.76041667 19929.75
#  19929.73958333 19929.72916667 19929.71875    19929.70833333
#  19929.69791667 19929.6875     19929.67708333 19929.66666667
#  19929.65625    19929.64583333 19929.63541667 19929.625
#  19929.61458333 19929.60416667 19929.59375    19929.58333333
#  19929.57291667 19929.5625     19929.55208333 19929.54166667
#  19929.53125    19929.52083333 19929.51041667 19929.5
#  19929.48958333 19929.47916667 19929.46875    19929.45833333]

# %%
"""# importing pandas as pd
import pandas as pd


# list of name, degree, score
nme = ["aparna", "pankaj", "sudhir", "Geeku"]
deg = ["MBA", "BCA", "M.Tech", "MBA"]
scr = [90, 40, 80, 98]

# dictionary of lists
dict = {'name': nme, 'degree': deg, 'score': scr}

df = pd.DataFrame(dict)

# saving the dataframe
df.to_csv('GFG.csv')"""
# Out:
# '# importing pandas as pd\nimport pandas as pd\n\n\n# list of name, degree, score\nnme = ["aparna", "pankaj", "sudhir", "Geeku"]\ndeg = ["MBA", "BCA", "M.Tech", "MBA"]\nscr = [90, 40, 80, 98]\n\n# dictionary of lists\ndict = {\'name\': nme, \'degree\': deg, \'score\': scr}\n\ndf = pd.DataFrame(dict)\n\n# saving the dataframe\ndf.to_csv(\'GFG.csv\')'

# %%
#1. data processing
#2. get the data of opening and closing rate
#3. get news data of that particular date
#4. perform sentiment analysis on new data
#5. get sentiment score
#6. get the avg of compound data
#7. test regression model using stock and avg data
#8. compare with stock prices of next day
#9. find loss
#10. train until model reaches required accuracy
